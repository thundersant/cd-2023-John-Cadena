# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from matplotlib import colors
from scipy.stats import pearsonr, zscore

import statsmodels.api as sm
import statsmodels.formula.api as smf

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import linear_model

# %%
#Datos de propiedades
ruta = 'https://raw.githubusercontent.com/rasief/cartografia/master/melb_data.csv'
df = pd.read_csv(ruta)

# %%
df
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 0        Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0
# 1        Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0
# 2        Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0
# 3        Biggin   4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0
# 4        Nelson   4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0
# ...         ...         ...       ...       ...  ...       ...  ...       ...
# 13575     Barry  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13576  Williams  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13577     Raine  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13578   Sweeney  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13579   Village  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0               NaN        NaN        Yarra -37.79960   144.99840
# 1              79.0     1900.0        Yarra -37.80790   144.99340
# 2             150.0     1900.0        Yarra -37.80930   144.99440
# 3               NaN        NaN        Yarra -37.79690   144.99690
# 4             142.0     2014.0        Yarra -37.80720   144.99410
# ...             ...        ...          ...       ...         ...
# 13575           NaN     1981.0          NaN -37.90562   145.16761
# 13576         133.0     1995.0          NaN -37.85927   144.87904
# 13577           NaN     1997.0          NaN -37.85274   144.88738
# 13578         157.0     1920.0          NaN -37.85908   144.89299
# 13579         112.0     1920.0          NaN -37.81188   144.88449
#
#                        Regionname Propertycount
# 0           Northern Metropolitan        4019.0
# 1           Northern Metropolitan        4019.0
# 2           Northern Metropolitan        4019.0
# 3           Northern Metropolitan        4019.0
# 4           Northern Metropolitan        4019.0
# ...                           ...           ...
# 13575  South-Eastern Metropolitan        7392.0
# 13576        Western Metropolitan        6380.0
# 13577        Western Metropolitan        6380.0
# 13578        Western Metropolitan        6380.0
# 13579        Western Metropolitan        6543.0
#
# [13580 rows x 21 columns]

# %%
df.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
df = df.select_dtypes(exclude=['object'])
df
# Out:
#        Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 0          2  1480000.0       2.5    3067.0       2.0       1.0  1.0
# 1          2  1035000.0       2.5    3067.0       2.0       1.0  0.0
# 2          3  1465000.0       2.5    3067.0       3.0       2.0  0.0
# 3          3   850000.0       2.5    3067.0       3.0       2.0  1.0
# 4          4  1600000.0       2.5    3067.0       3.0       1.0  2.0
# ...      ...        ...       ...       ...       ...       ...  ...
# 13575      4  1245000.0      16.7    3150.0       4.0       2.0  2.0
# 13576      3  1031000.0       6.8    3016.0       3.0       2.0  2.0
# 13577      3  1170000.0       6.8    3016.0       3.0       2.0  4.0
# 13578      4  2500000.0       6.8    3016.0       4.0       1.0  5.0
# 13579      4  1285000.0       6.3    3013.0       4.0       1.0  1.0
#
#        Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude  Propertycount
# 0         202.0           NaN        NaN  -37.79960   144.99840         4019.0
# 1         156.0          79.0     1900.0  -37.80790   144.99340         4019.0
# 2         134.0         150.0     1900.0  -37.80930   144.99440         4019.0
# 3          94.0           NaN        NaN  -37.79690   144.99690         4019.0
# 4         120.0         142.0     2014.0  -37.80720   144.99410         4019.0
# ...         ...           ...        ...        ...         ...            ...
# 13575     652.0           NaN     1981.0  -37.90562   145.16761         7392.0
# 13576     333.0         133.0     1995.0  -37.85927   144.87904         6380.0
# 13577     436.0           NaN     1997.0  -37.85274   144.88738         6380.0
# 13578     866.0         157.0     1920.0  -37.85908   144.89299         6380.0
# 13579     362.0         112.0     1920.0  -37.81188   144.88449         6543.0
#
# [13580 rows x 13 columns]

# %%
#Buscar nulos
df.isnull().sum()
# Out:
# Rooms               0
# Price               0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# Lattitude           0
# Longtitude          0
# Propertycount       0
# dtype: int64

# %%
#Histograma
df.Price.hist(color='blue', bins=100, figsize=(10, 6))

# %%
df = df.dropna()
df
# Out:
#        Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 1          2  1035000.0       2.5    3067.0       2.0       1.0  0.0
# 2          3  1465000.0       2.5    3067.0       3.0       2.0  0.0
# 4          4  1600000.0       2.5    3067.0       3.0       1.0  2.0
# 6          3  1876000.0       2.5    3067.0       4.0       2.0  0.0
# 7          2  1636000.0       2.5    3067.0       2.0       1.0  2.0
# ...      ...        ...       ...       ...       ...       ...  ...
# 13572      2   650000.0      14.5    3087.0       2.0       1.0  1.0
# 13573      4   635000.0      14.7    3030.0       4.0       2.0  1.0
# 13576      3  1031000.0       6.8    3016.0       3.0       2.0  2.0
# 13578      4  2500000.0       6.8    3016.0       4.0       1.0  5.0
# 13579      4  1285000.0       6.3    3013.0       4.0       1.0  1.0
#
#        Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude  Propertycount
# 1         156.0          79.0     1900.0  -37.80790   144.99340         4019.0
# 2         134.0         150.0     1900.0  -37.80930   144.99440         4019.0
# 4         120.0         142.0     2014.0  -37.80720   144.99410         4019.0
# 6         245.0         210.0     1910.0  -37.80240   144.99930         4019.0
# 7         256.0         107.0     1890.0  -37.80600   144.99540         4019.0
# ...         ...           ...        ...        ...         ...            ...
# 13572     210.0          79.0     2006.0  -37.70657   145.07878         2329.0
# 13573     662.0         172.0     1980.0  -37.89327   144.64789        16166.0
# 13576     333.0         133.0     1995.0  -37.85927   144.87904         6380.0
# 13578     866.0         157.0     1920.0  -37.85908   144.89299         6380.0
# 13579     362.0         112.0     1920.0  -37.81188   144.88449         6543.0
#
# [6830 rows x 13 columns]

# %%
#Buscar nulos
df.isnull().sum()
# Out:
# Rooms            0
# Price            0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# Lattitude        0
# Longtitude       0
# Propertycount    0
# dtype: int64

# %%
#Diagrama de distribución
fig, ax = plt.subplots(figsize=(10, 6))
df.plot(x = 'BuildingArea', y = 'Price', c = 'green', kind = "scatter", ax = ax)
ax.set_title('Distribución de precio y area construida');

# %%
#Datos con área menor o igual a 800
df0 = df[df["BuildingArea"]<=800]

# %%
#Diagrama de distribución
fig, ax = plt.subplots(figsize=(10, 6))
df0.plot(x = 'BuildingArea', y = 'Price', c = 'purple', kind = "scatter", ax = ax)
ax.set_title('Distribución de precio y area construida');

# %%
#Datos con área cero
dfzero = df0[df0["BuildingArea"]==0]
dfzero
# Out:
#        Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 4344       2   841000.0       2.3    3051.0       2.0       1.0  1.0
# 12226      5  1950000.0       9.7    3104.0       5.0       3.0  2.0
# 12249      3   814000.0      12.1    3083.0       3.0       1.0  2.0
# 12395      4   570000.0      20.6    3064.0       4.0       2.0  2.0
# 12412      3   900000.0       7.0    3071.0       3.0       2.0  2.0
# 13040      3  1390000.0       4.6    3181.0       3.0       2.0  1.0
# 13207      3  1205000.0      12.3    3166.0       3.0       2.0  4.0
# 13348      5  2800000.0       9.7    3104.0       5.0       2.0  2.0
# 13370      3  1650000.0      10.3    3187.0       3.0       2.0  2.0
# 13380      4   815000.0      12.1    3083.0       4.0       2.0  1.0
# 13402      3   412500.0      20.6    3064.0       3.0       2.0  1.0
# 13411      3   595000.0      19.6    3076.0       3.0       1.0  2.0
# 13434      4  2690000.0       7.3    3146.0       4.0       2.0  2.0
# 13468      5  3450000.0       5.4    3101.0       5.0       2.0  2.0
# 13472      3   803000.0      26.0    3137.0       3.0       1.0  2.0
# 13499      3  1290000.0      14.3    3189.0       3.0       1.0  1.0
# 13521      4  2455000.0       3.5    3207.0       4.0       3.0  2.0
#
#        Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude  Propertycount
# 4344      215.0           0.0     2000.0  -37.79530   144.94370         6821.0
# 12226     743.0           0.0     1949.0  -37.80235   145.09311         7809.0
# 12249     542.0           0.0     1970.0  -37.70861   145.05691        10175.0
# 12395     504.0           0.0     2000.0  -37.61419   144.93448         5833.0
# 12412     120.0           0.0     2000.0  -37.76343   145.02096         8870.0
# 13040     125.0           0.0     2002.0  -37.85257   145.00296         7717.0
# 13207     622.0           0.0     1960.0  -37.90823   145.10851          768.0
# 13348    1173.0           0.0     1960.0  -37.80385   145.09094         7809.0
# 13370     623.0           0.0     1920.0  -37.92698   145.02673         6938.0
# 13380     525.0           0.0     1965.0  -37.70765   145.05556        10175.0
# 13402     197.0           0.0     2012.0  -37.57687   144.91100        15510.0
# 13411     536.0           0.0     1980.0  -37.64972   145.04086        10926.0
# 13434     647.0           0.0     1910.0  -37.86133   145.04167        10412.0
# 13468     668.0           0.0     2006.0  -37.80795   145.01474        10331.0
# 13472     862.0           0.0     1970.0  -37.79902   145.32092         4654.0
# 13499     580.0           0.0     1970.0  -37.94492   145.04938         2555.0
# 13521     123.0           0.0     2010.0  -37.83349   144.94840         8648.0

# %%
#Se eliminan los registros de menos de 15 mts cuadrados de area
df0 = df0[df0["BuildingArea"]>15]

# %%
#Se eliminan todos los datos que estén más allá de 3 desviaciones estándar
df0 = df0[(np.abs(zscore(df0['Price']))<=3)]
df0
# Out:
#        Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 1          2  1035000.0       2.5    3067.0       2.0       1.0  0.0
# 2          3  1465000.0       2.5    3067.0       3.0       2.0  0.0
# 4          4  1600000.0       2.5    3067.0       3.0       1.0  2.0
# 6          3  1876000.0       2.5    3067.0       4.0       2.0  0.0
# 7          2  1636000.0       2.5    3067.0       2.0       1.0  2.0
# ...      ...        ...       ...       ...       ...       ...  ...
# 13572      2   650000.0      14.5    3087.0       2.0       1.0  1.0
# 13573      4   635000.0      14.7    3030.0       4.0       2.0  1.0
# 13576      3  1031000.0       6.8    3016.0       3.0       2.0  2.0
# 13578      4  2500000.0       6.8    3016.0       4.0       1.0  5.0
# 13579      4  1285000.0       6.3    3013.0       4.0       1.0  1.0
#
#        Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude  Propertycount
# 1         156.0          79.0     1900.0  -37.80790   144.99340         4019.0
# 2         134.0         150.0     1900.0  -37.80930   144.99440         4019.0
# 4         120.0         142.0     2014.0  -37.80720   144.99410         4019.0
# 6         245.0         210.0     1910.0  -37.80240   144.99930         4019.0
# 7         256.0         107.0     1890.0  -37.80600   144.99540         4019.0
# ...         ...           ...        ...        ...         ...            ...
# 13572     210.0          79.0     2006.0  -37.70657   145.07878         2329.0
# 13573     662.0         172.0     1980.0  -37.89327   144.64789        16166.0
# 13576     333.0         133.0     1995.0  -37.85927   144.87904         6380.0
# 13578     866.0         157.0     1920.0  -37.85908   144.89299         6380.0
# 13579     362.0         112.0     1920.0  -37.81188   144.88449         6543.0
#
# [6654 rows x 13 columns]

# %%
#Diagrama de distribución
fig, ax = plt.subplots(figsize=(10, 6))
df0.plot(x = 'BuildingArea', y = 'Price', c = 'lime', kind = "scatter", ax = ax)
ax.set_title('Distribución de precio y area construida');

# %%
#Datos con área cero
dfzero = df0[df0["BuildingArea"]<=15]
len(dfzero)
# Out:
# 0

# %%
#Se eliminan los registros de menos de 15 mts cuadrados de area
df0 = df0[df0["BuildingArea"]>15]

# %%
#Se eliminan todos los datos que estén más allá de 3 desviaciones estándar
df0 = df0[(np.abs(zscore(df0['Price']))<=3)]
df0
# Out:
#        Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 1          2  1035000.0       2.5    3067.0       2.0       1.0  0.0
# 2          3  1465000.0       2.5    3067.0       3.0       2.0  0.0
# 4          4  1600000.0       2.5    3067.0       3.0       1.0  2.0
# 6          3  1876000.0       2.5    3067.0       4.0       2.0  0.0
# 7          2  1636000.0       2.5    3067.0       2.0       1.0  2.0
# ...      ...        ...       ...       ...       ...       ...  ...
# 13572      2   650000.0      14.5    3087.0       2.0       1.0  1.0
# 13573      4   635000.0      14.7    3030.0       4.0       2.0  1.0
# 13576      3  1031000.0       6.8    3016.0       3.0       2.0  2.0
# 13578      4  2500000.0       6.8    3016.0       4.0       1.0  5.0
# 13579      4  1285000.0       6.3    3013.0       4.0       1.0  1.0
#
#        Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude  Propertycount
# 1         156.0          79.0     1900.0  -37.80790   144.99340         4019.0
# 2         134.0         150.0     1900.0  -37.80930   144.99440         4019.0
# 4         120.0         142.0     2014.0  -37.80720   144.99410         4019.0
# 6         245.0         210.0     1910.0  -37.80240   144.99930         4019.0
# 7         256.0         107.0     1890.0  -37.80600   144.99540         4019.0
# ...         ...           ...        ...        ...         ...            ...
# 13572     210.0          79.0     2006.0  -37.70657   145.07878         2329.0
# 13573     662.0         172.0     1980.0  -37.89327   144.64789        16166.0
# 13576     333.0         133.0     1995.0  -37.85927   144.87904         6380.0
# 13578     866.0         157.0     1920.0  -37.85908   144.89299         6380.0
# 13579     362.0         112.0     1920.0  -37.81188   144.88449         6543.0
#
# [6566 rows x 13 columns]

# %%
#Histograma
df0.Price.hist(color='firebrick', bins=50, figsize=(10, 6))

# %%
#Boxplot
ax = sb.boxplot(data=df0['BuildingArea'].values, orient='h', color='yellow')
ax.set_title('Boxplot area construida');
plt.show()

# %%
#Múltiples diagramas por parejas
#sb.set_theme(style="ticks")
#sb.pairplot(df0, hue='Rooms')

# %%
#Múltiples diagramas por parejas
#sb.set_theme(style="ticks")
#sb.pairplot(df0, hue='Price')

# %%
#Correlación entre variables
corr_test = pearsonr(x = df['BuildingArea'], y = df['Price'])
print("Coeficiente de correlación de Pearson: ", corr_test[0])
print("P-value: ", corr_test[1])
# Out:
# Coeficiente de correlación de Pearson:  0.5204915813803511
# P-value:  0.0

# %%
colormap = plt.cm.viridis
plt.figure(figsize=(10, 10))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sb.heatmap(df.astype(float).corr(),linewidths=0.1,vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True)

# %%
#Datos de propiedades
ruta = 'https://raw.githubusercontent.com/rasief/cartografia/master/melb_data.csv'
dfo = pd.read_csv(ruta)

# %%
dfo = dfo.select_dtypes(exclude=['object'])
dfo
# Out:
#        Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 0          2  1480000.0       2.5    3067.0       2.0       1.0  1.0
# 1          2  1035000.0       2.5    3067.0       2.0       1.0  0.0
# 2          3  1465000.0       2.5    3067.0       3.0       2.0  0.0
# 3          3   850000.0       2.5    3067.0       3.0       2.0  1.0
# 4          4  1600000.0       2.5    3067.0       3.0       1.0  2.0
# ...      ...        ...       ...       ...       ...       ...  ...
# 13575      4  1245000.0      16.7    3150.0       4.0       2.0  2.0
# 13576      3  1031000.0       6.8    3016.0       3.0       2.0  2.0
# 13577      3  1170000.0       6.8    3016.0       3.0       2.0  4.0
# 13578      4  2500000.0       6.8    3016.0       4.0       1.0  5.0
# 13579      4  1285000.0       6.3    3013.0       4.0       1.0  1.0
#
#        Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude  Propertycount
# 0         202.0           NaN        NaN  -37.79960   144.99840         4019.0
# 1         156.0          79.0     1900.0  -37.80790   144.99340         4019.0
# 2         134.0         150.0     1900.0  -37.80930   144.99440         4019.0
# 3          94.0           NaN        NaN  -37.79690   144.99690         4019.0
# 4         120.0         142.0     2014.0  -37.80720   144.99410         4019.0
# ...         ...           ...        ...        ...         ...            ...
# 13575     652.0           NaN     1981.0  -37.90562   145.16761         7392.0
# 13576     333.0         133.0     1995.0  -37.85927   144.87904         6380.0
# 13577     436.0           NaN     1997.0  -37.85274   144.88738         6380.0
# 13578     866.0         157.0     1920.0  -37.85908   144.89299         6380.0
# 13579     362.0         112.0     1920.0  -37.81188   144.88449         6543.0
#
# [13580 rows x 13 columns]

# %%
#Borrado de datos nulos
dfo = dfo.dropna()
dfo
# Out:
#        Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 1          2  1035000.0       2.5    3067.0       2.0       1.0  0.0
# 2          3  1465000.0       2.5    3067.0       3.0       2.0  0.0
# 4          4  1600000.0       2.5    3067.0       3.0       1.0  2.0
# 6          3  1876000.0       2.5    3067.0       4.0       2.0  0.0
# 7          2  1636000.0       2.5    3067.0       2.0       1.0  2.0
# ...      ...        ...       ...       ...       ...       ...  ...
# 13572      2   650000.0      14.5    3087.0       2.0       1.0  1.0
# 13573      4   635000.0      14.7    3030.0       4.0       2.0  1.0
# 13576      3  1031000.0       6.8    3016.0       3.0       2.0  2.0
# 13578      4  2500000.0       6.8    3016.0       4.0       1.0  5.0
# 13579      4  1285000.0       6.3    3013.0       4.0       1.0  1.0
#
#        Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude  Propertycount
# 1         156.0          79.0     1900.0  -37.80790   144.99340         4019.0
# 2         134.0         150.0     1900.0  -37.80930   144.99440         4019.0
# 4         120.0         142.0     2014.0  -37.80720   144.99410         4019.0
# 6         245.0         210.0     1910.0  -37.80240   144.99930         4019.0
# 7         256.0         107.0     1890.0  -37.80600   144.99540         4019.0
# ...         ...           ...        ...        ...         ...            ...
# 13572     210.0          79.0     2006.0  -37.70657   145.07878         2329.0
# 13573     662.0         172.0     1980.0  -37.89327   144.64789        16166.0
# 13576     333.0         133.0     1995.0  -37.85927   144.87904         6380.0
# 13578     866.0         157.0     1920.0  -37.85908   144.89299         6380.0
# 13579     362.0         112.0     1920.0  -37.81188   144.88449         6543.0
#
# [6830 rows x 13 columns]

# %%
#Remover valores más allá de 3 desviaciones entándar
df1 = dfo.copy()
for columna in df1:
  df1 = df1[(np.abs(zscore(df1[columna]))<=3)]
df1
# Out:
#        Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 1          2  1035000.0       2.5    3067.0       2.0       1.0  0.0
# 2          3  1465000.0       2.5    3067.0       3.0       2.0  0.0
# 4          4  1600000.0       2.5    3067.0       3.0       1.0  2.0
# 6          3  1876000.0       2.5    3067.0       4.0       2.0  0.0
# 7          2  1636000.0       2.5    3067.0       2.0       1.0  2.0
# ...      ...        ...       ...       ...       ...       ...  ...
# 13568      4   951000.0      14.7    3152.0       4.0       2.0  2.0
# 13571      4  1330000.0      14.7    3152.0       4.0       2.0  2.0
# 13572      2   650000.0      14.5    3087.0       2.0       1.0  1.0
# 13576      3  1031000.0       6.8    3016.0       3.0       2.0  2.0
# 13579      4  1285000.0       6.3    3013.0       4.0       1.0  1.0
#
#        Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude  Propertycount
# 1         156.0          79.0     1900.0  -37.80790   144.99340         4019.0
# 2         134.0         150.0     1900.0  -37.80930   144.99440         4019.0
# 4         120.0         142.0     2014.0  -37.80720   144.99410         4019.0
# 6         245.0         210.0     1910.0  -37.80240   144.99930         4019.0
# 7         256.0         107.0     1890.0  -37.80600   144.99540         4019.0
# ...         ...           ...        ...        ...         ...            ...
# 13568     704.0         200.0     1981.0  -37.85639   145.23536         5424.0
# 13571     717.0         191.0     1980.0  -37.86887   145.22116         7082.0
# 13572     210.0          79.0     2006.0  -37.70657   145.07878         2329.0
# 13576     333.0         133.0     1995.0  -37.85927   144.87904         6380.0
# 13579     362.0         112.0     1920.0  -37.81188   144.88449         6543.0
#
# [6005 rows x 13 columns]

# %%
colormap = plt.cm.viridis
plt.figure(figsize=(10, 10))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sb.heatmap(df1.astype(float).corr(),linewidths=0.1,vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True)

# %%
sb.set_theme(color_codes=True)
sb.set_theme(style="ticks")
ax = sb.regplot(x="BuildingArea", y="Price", data=df1, marker='+', x_jitter=0.2, y_jitter=0.2)
ax.set_title('Distribución de precio y area construida')
# Out:
# Text(0.5, 1.0, 'Distribución de precio y area construida')

# %%
#Múltiples diagramas por parejas
sb.set_theme(style="ticks")
sb.pairplot(df0, kind='reg')

# %%
#Regresión lineal (Area construida vs. Precio)
x = df1["BuildingArea"]
y = df1["Price"]
x2 = sm.add_constant(x)
est = sm.OLS(y, x2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.392
# Model:                            OLS   Adj. R-squared:                  0.392
# Method:                 Least Squares   F-statistic:                     3877.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:16:24   Log-Likelihood:                -86205.
# No. Observations:                6005   AIC:                         1.724e+05
# Df Residuals:                    6003   BIC:                         1.724e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         3.254e+05   1.27e+04     25.652      0.000    3.01e+05     3.5e+05
# BuildingArea  5345.7152     85.855     62.265      0.000    5177.409    5514.021
# ==============================================================================
# Omnibus:                      921.026   Durbin-Watson:                   1.421
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1990.795
# Skew:                           0.909   Prob(JB):                         0.00
# Kurtosis:                       5.157   Cond. No.                         350.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
df1.dtypes
# Out:
# Rooms              int64
# Price            float64
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# Lattitude        float64
# Longtitude       float64
# Propertycount    float64
# dtype: object

# %%
#Regresión lineal múltiple
#x = df1.iloc[:,[0,2,4,5,6,7,8,9,12]]
x = df1.iloc[:,[2,4,5,6,7,8,9,12]]
#x = df1.iloc[:,[2,5,6,7,8,9,12]]
y = df1["Price"]
x2 = sm.add_constant(x)
est = sm.OLS(y, x2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.613
# Model:                            OLS   Adj. R-squared:                  0.612
# Method:                 Least Squares   F-statistic:                     1185.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:16:24   Log-Likelihood:                -84854.
# No. Observations:                6005   AIC:                         1.697e+05
# Df Residuals:                    5996   BIC:                         1.698e+05
# Df Model:                           8
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          9.876e+06   2.55e+05     38.709      0.000    9.38e+06    1.04e+07
# Distance      -2.725e+04   1099.221    -24.794      0.000   -2.94e+04   -2.51e+04
# Bedroom2       7.959e+04   7593.945     10.481      0.000    6.47e+04    9.45e+04
# Bathroom       1.394e+05   9554.083     14.594      0.000    1.21e+05    1.58e+05
# Car            4.655e+04   6042.410      7.705      0.000    3.47e+04    5.84e+04
# Landsize        113.0368     13.673      8.267      0.000      86.234     139.840
# BuildingArea   3780.7616    109.739     34.452      0.000    3565.634    3995.890
# YearBuilt     -4933.6289    130.630    -37.768      0.000   -5189.710   -4677.548
# Propertycount     5.8177      1.199      4.853      0.000       3.468       8.168
# ==============================================================================
# Omnibus:                      873.038   Durbin-Watson:                   1.481
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2051.442
# Skew:                           0.839   Prob(JB):                         0.00
# Kurtosis:                       5.321   Cond. No.                     4.80e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.8e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
#Predicciones con scikit-learn
train, test = train_test_split(df1, test_size = 0.20)
print("Ejemplos usados para entrenar: ", len(train))
print("Ejemplos usados para test: ", len(test))
# Out:
# Ejemplos usados para entrenar:  4804
# Ejemplos usados para test:  1201

# %%
#Se definen las variables
x_train = train.iloc[:,[2,4,5,6,7,8,9,12]]
y_train = train.Price
x_test = test.iloc[:,[2,4,5,6,7,8,9,12]]
y_test = test.Price

# %%
#Entrenamiento del modelo
regr = LinearRegression()
regr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_train
# Out:
# 5819      400000.0
# 4246     1280000.0
# 11366     945000.0
# 2944      670000.0
# 870      1200000.0
#            ...
# 857      1050000.0
# 1592     1800000.0
# 2433     1600000.0
# 11364     395000.0
# 6982     1738000.0
# Name: Price, Length: 4804, dtype: float64

# %%
x_train
# Out:
#        Distance  Bedroom2  Bathroom  Car  Landsize  BuildingArea  YearBuilt  \
# 5819        6.1       2.0       1.0  1.0       0.0          65.0     1970.0
# 4246        8.4       4.0       2.0  1.0     458.0         153.0     1930.0
# 11366      15.4       4.0       2.0  2.0     294.0         194.0     2010.0
# 2944       13.0       3.0       1.0  3.0     705.0         135.0     1950.0
# 870        13.9       3.0       1.0  1.0     721.0         120.0     1970.0
# ...         ...       ...       ...  ...       ...           ...        ...
# 857        13.9       3.0       1.0  4.0     726.0         131.0     1950.0
# 1592        7.8       3.0       2.0  0.0     584.0         213.0     1920.0
# 2433        8.0       4.0       3.0  1.0     519.0         218.0     1930.0
# 11364       5.1       2.0       1.0  1.0       0.0          73.0     1970.0
# 6982        7.5       4.0       3.0  2.0     324.0         241.0     2002.0
#
#        Propertycount
# 5819         13240.0
# 4246          5498.0
# 11366         4385.0
# 2944          8870.0
# 870          10969.0
# ...              ...
# 857          10969.0
# 1592          8920.0
# 2433          9264.0
# 11364         7570.0
# 6982          6482.0
#
# [4804 rows x 8 columns]

# %%
#Regresión lineal múltiple de los datos de prueba
x = x_train
y = y_train
x2 = sm.add_constant(x)
est = sm.OLS(y, x2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.613
# Model:                            OLS   Adj. R-squared:                  0.613
# Method:                 Least Squares   F-statistic:                     951.0
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:16:24   Log-Likelihood:                -67850.
# No. Observations:                4804   AIC:                         1.357e+05
# Df Residuals:                    4795   BIC:                         1.358e+05
# Df Model:                           8
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          9.663e+06   2.85e+05     33.909      0.000     9.1e+06    1.02e+07
# Distance      -2.776e+04   1227.723    -22.611      0.000   -3.02e+04   -2.54e+04
# Bedroom2       7.736e+04   8458.277      9.146      0.000    6.08e+04    9.39e+04
# Bathroom       1.404e+05   1.06e+04     13.205      0.000     1.2e+05    1.61e+05
# Car            4.246e+04   6657.617      6.378      0.000    2.94e+04    5.55e+04
# Landsize        118.2356     15.422      7.667      0.000      88.002     148.469
# BuildingArea   3783.2309    121.622     31.106      0.000    3544.796    4021.666
# YearBuilt     -4817.8034    145.997    -32.999      0.000   -5104.025   -4531.582
# Propertycount     5.4100      1.338      4.042      0.000       2.786       8.034
# ==============================================================================
# Omnibus:                      703.651   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1618.753
# Skew:                           0.850   Prob(JB):                         0.00
# Kurtosis:                       5.280   Cond. No.                     4.80e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.8e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
predicciones = regr.predict(x_train)
for y, y_pred in list(zip(y_train, predicciones)) [:10]:
    print("Valor real: {:.2f} - Valor estimado: {:.2f}".format(y, y_pred))
# Out:
# Valor real: 400000.00 - Valor estimado: 657510.33
# Valor real: 1280000.00 - Valor estimado: 1426673.87
# Valor real: 945000.00 - Valor estimado: 1019096.46
# Valor real: 670000.00 - Valor estimado: 1049155.94
# Valor real: 1200000.00 - Valor estimado: 799388.58
# Valor real: 428000.00 - Valor estimado: 340197.60
# Valor real: 1636000.00 - Valor estimado: 1324611.01
# Valor real: 1731000.00 - Valor estimado: 1534496.98
# Valor real: 1316000.00 - Valor estimado: 870308.40
# Valor real: 1916000.00 - Valor estimado: 1755155.86

# %%
import itertools

# %%
#compara una sola
variables =['Rooms', 'Distance','Bedroom2', 'Car','Landsize','BuildingArea','YearBuilt','Propertycount','Lattitude','Longtitude']
for col1 in variables:
    x = df1[[col1]]
    y = df1['Price']
    x2 = sm.add_constant(x)
    est = sm.OLS(y, x2)
    est2 = est.fit()
    print("\nVariable: ", col1)
    print(est2.summary())

    plt.scatter(x, y)
    plt.plot(x, est2.predict(x2), color='red')
    plt.xlabel(col1)
    plt.ylabel('Price')
    plt.title('Regresión lineal de la variable ' + col1)
    plt.show()
    best_r2 = 0
best_col = ''
for col1 in variables:
    x = df1[[col1]]
    y = df1['Price']
    x2 = sm.add_constant(x)
    est = sm.OLS(y, x2)
    est2 = est.fit()
    r2 = est2.rsquared
    if r2 > best_r2:
        best_r2 = r2
        best_col = col1
    print("\nVariable: ", col1)
    print(est2.summary())

    plt.scatter(x, y)
    plt.plot(x, est2.predict(x2), color='red')
    plt.xlabel(col1)
    plt.ylabel('Price')
    plt.title('Regresión lineal de la variable ' + col1)
    plt.show()

print("Mejor al cuadrado:", best_r2)
print("Mejor variable:", best_col)
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# Variable:  Rooms
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.306
# Model:                            OLS   Adj. R-squared:                  0.306
# Method:                 Least Squares   F-statistic:                     2646.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:52:44   Log-Likelihood:                -86605.
# No. Observations:                6005   AIC:                         1.732e+05
# Df Residuals:                    6003   BIC:                         1.732e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.078e+05    1.9e+04      5.663      0.000    7.05e+04    1.45e+05
# Rooms       3.221e+05   6262.571     51.436      0.000     3.1e+05    3.34e+05
# ==============================================================================
# Omnibus:                      912.500   Durbin-Watson:                   1.315
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1558.894
# Skew:                           1.001   Prob(JB):                         0.00
# Kurtosis:                       4.491   Cond. No.                         11.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# Variable:  Distance
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     69.15
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):           1.12e-16
# Time:                        23:52:45   Log-Likelihood:                -87667.
# No. Observations:                6005   AIC:                         1.753e+05
# Df Residuals:                    6003   BIC:                         1.754e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.156e+06   1.54e+04     74.992      0.000    1.13e+06    1.19e+06
# Distance    -1.23e+04   1478.716     -8.316      0.000   -1.52e+04   -9397.659
# ==============================================================================
# Omnibus:                      890.745   Durbin-Watson:                   1.480
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1365.709
# Skew:                           1.057   Prob(JB):                    2.76e-297
# Kurtosis:                       3.994   Cond. No.                         23.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# Variable:  Bedroom2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.294
# Model:                            OLS   Adj. R-squared:                  0.294
# Method:                 Least Squares   F-statistic:                     2495.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:52:45   Log-Likelihood:                -86658.
# No. Observations:                6005   AIC:                         1.733e+05
# Df Residuals:                    6003   BIC:                         1.733e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.317e+05   1.91e+04      6.892      0.000    9.42e+04    1.69e+05
# Bedroom2    3.166e+05   6337.062     49.953      0.000    3.04e+05    3.29e+05
# ==============================================================================
# Omnibus:                      916.729   Durbin-Watson:                   1.332
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1568.044
# Skew:                           1.005   Prob(JB):                         0.00
# Kurtosis:                       4.493   Cond. No.                         11.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# Variable:  Car
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.060
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     382.6
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):           1.22e-82
# Time:                        23:52:45   Log-Likelihood:                -87516.
# No. Observations:                6005   AIC:                         1.750e+05
# Df Residuals:                    6003   BIC:                         1.750e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       8.002e+05    1.4e+04     57.107      0.000    7.73e+05    8.28e+05
# Car         1.588e+05   8118.588     19.560      0.000    1.43e+05    1.75e+05
# ==============================================================================
# Omnibus:                      941.125   Durbin-Watson:                   1.472
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1471.215
# Skew:                           1.100   Prob(JB):                         0.00
# Kurtosis:                       4.022   Cond. No.                         4.63
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# Variable:  Landsize
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.060
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     380.9
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):           2.64e-82
# Time:                        23:52:45   Log-Likelihood:                -87517.
# No. Observations:                6005   AIC:                         1.750e+05
# Df Residuals:                    6003   BIC:                         1.751e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       8.906e+05   1.02e+04     87.332      0.000    8.71e+05    9.11e+05
# Landsize     372.9616     19.109     19.518      0.000     335.501     410.422
# ==============================================================================
# Omnibus:                      799.967   Durbin-Watson:                   1.457
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1224.001
# Skew:                           0.952   Prob(JB):                    1.63e-266
# Kurtosis:                       4.124   Cond. No.                         816.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# Variable:  BuildingArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.392
# Model:                            OLS   Adj. R-squared:                  0.392
# Method:                 Least Squares   F-statistic:                     3877.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:52:46   Log-Likelihood:                -86205.
# No. Observations:                6005   AIC:                         1.724e+05
# Df Residuals:                    6003   BIC:                         1.724e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         3.254e+05   1.27e+04     25.652      0.000    3.01e+05     3.5e+05
# BuildingArea  5345.7152     85.855     62.265      0.000    5177.409    5514.021
# ==============================================================================
# Omnibus:                      921.026   Durbin-Watson:                   1.421
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1990.795
# Skew:                           0.909   Prob(JB):                         0.00
# Kurtosis:                       5.157   Cond. No.                         350.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# Variable:  YearBuilt
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.134
# Model:                            OLS   Adj. R-squared:                  0.134
# Method:                 Least Squares   F-statistic:                     928.1
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):          1.12e-189
# Time:                        23:52:46   Log-Likelihood:                -87270.
# No. Observations:                6005   AIC:                         1.745e+05
# Df Residuals:                    6003   BIC:                         1.746e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.147e+07   3.42e+05     33.503      0.000    1.08e+07    1.21e+07
# YearBuilt  -5309.7615    174.289    -30.465      0.000   -5651.431   -4968.092
# ==============================================================================
# Omnibus:                     1094.107   Durbin-Watson:                   1.497
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1952.132
# Skew:                           1.159   Prob(JB):                         0.00
# Kurtosis:                       4.559   Cond. No.                     1.05e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.05e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# Variable:  Propertycount
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.591
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):              0.207
# Time:                        23:52:46   Log-Likelihood:                -87701.
# No. Observations:                6005   AIC:                         1.754e+05
# Df Residuals:                    6003   BIC:                         1.754e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          1.025e+06   1.48e+04     69.350      0.000    9.96e+05    1.05e+06
# Propertycount     2.3744      1.882      1.261      0.207      -1.316       6.064
# ==============================================================================
# Omnibus:                      942.503   Durbin-Watson:                   1.482
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1474.022
# Skew:                           1.101   Prob(JB):                         0.00
# Kurtosis:                       4.022   Cond. No.                     1.69e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.69e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# Variable:  Lattitude
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.063
# Model:                            OLS   Adj. R-squared:                  0.063
# Method:                 Least Squares   F-statistic:                     402.7
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):           9.50e-87
# Time:                        23:52:46   Log-Likelihood:                -87506.
# No. Observations:                6005   AIC:                         1.750e+05
# Df Residuals:                    6003   BIC:                         1.750e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -7.205e+07   3.64e+06    -19.781      0.000   -7.92e+07   -6.49e+07
# Lattitude  -1.933e+06   9.63e+04    -20.067      0.000   -2.12e+06   -1.74e+06
# ==============================================================================
# Omnibus:                      843.034   Durbin-Watson:                   1.550
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1284.851
# Skew:                           1.004   Prob(JB):                    9.96e-280
# Kurtosis:                       4.048   Cond. No.                     2.07e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.07e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# Variable:  Longtitude
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.057
# Model:                            OLS   Adj. R-squared:                  0.057
# Method:                 Least Squares   F-statistic:                     364.0
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):           7.73e-79
# Time:                        23:52:47   Log-Likelihood:                -87525.
# No. Observations:                6005   AIC:                         1.751e+05
# Df Residuals:                    6003   BIC:                         1.751e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2.011e+08   1.06e+07    -18.981      0.000   -2.22e+08    -1.8e+08
# Longtitude  1.394e+06   7.31e+04     19.080      0.000    1.25e+06    1.54e+06
# ==============================================================================
# Omnibus:                      924.597   Durbin-Watson:                   1.563
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1455.272
# Skew:                           1.071   Prob(JB):                         0.00
# Kurtosis:                       4.107   Cond. No.                     2.30e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.3e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# Variable:  Rooms
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.306
# Model:                            OLS   Adj. R-squared:                  0.306
# Method:                 Least Squares   F-statistic:                     2646.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:52:47   Log-Likelihood:                -86605.
# No. Observations:                6005   AIC:                         1.732e+05
# Df Residuals:                    6003   BIC:                         1.732e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.078e+05    1.9e+04      5.663      0.000    7.05e+04    1.45e+05
# Rooms       3.221e+05   6262.571     51.436      0.000     3.1e+05    3.34e+05
# ==============================================================================
# Omnibus:                      912.500   Durbin-Watson:                   1.315
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1558.894
# Skew:                           1.001   Prob(JB):                         0.00
# Kurtosis:                       4.491   Cond. No.                         11.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# Variable:  Distance
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     69.15
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):           1.12e-16
# Time:                        23:52:47   Log-Likelihood:                -87667.
# No. Observations:                6005   AIC:                         1.753e+05
# Df Residuals:                    6003   BIC:                         1.754e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.156e+06   1.54e+04     74.992      0.000    1.13e+06    1.19e+06
# Distance    -1.23e+04   1478.716     -8.316      0.000   -1.52e+04   -9397.659
# ==============================================================================
# Omnibus:                      890.745   Durbin-Watson:                   1.480
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1365.709
# Skew:                           1.057   Prob(JB):                    2.76e-297
# Kurtosis:                       3.994   Cond. No.                         23.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# Variable:  Bedroom2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.294
# Model:                            OLS   Adj. R-squared:                  0.294
# Method:                 Least Squares   F-statistic:                     2495.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:52:47   Log-Likelihood:                -86658.
# No. Observations:                6005   AIC:                         1.733e+05
# Df Residuals:                    6003   BIC:                         1.733e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.317e+05   1.91e+04      6.892      0.000    9.42e+04    1.69e+05
# Bedroom2    3.166e+05   6337.062     49.953      0.000    3.04e+05    3.29e+05
# ==============================================================================
# Omnibus:                      916.729   Durbin-Watson:                   1.332
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1568.044
# Skew:                           1.005   Prob(JB):                         0.00
# Kurtosis:                       4.493   Cond. No.                         11.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# Variable:  Car
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.060
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     382.6
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):           1.22e-82
# Time:                        23:52:48   Log-Likelihood:                -87516.
# No. Observations:                6005   AIC:                         1.750e+05
# Df Residuals:                    6003   BIC:                         1.750e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       8.002e+05    1.4e+04     57.107      0.000    7.73e+05    8.28e+05
# Car         1.588e+05   8118.588     19.560      0.000    1.43e+05    1.75e+05
# ==============================================================================
# Omnibus:                      941.125   Durbin-Watson:                   1.472
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1471.215
# Skew:                           1.100   Prob(JB):                         0.00
# Kurtosis:                       4.022   Cond. No.                         4.63
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# Variable:  Landsize
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.060
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     380.9
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):           2.64e-82
# Time:                        23:52:48   Log-Likelihood:                -87517.
# No. Observations:                6005   AIC:                         1.750e+05
# Df Residuals:                    6003   BIC:                         1.751e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       8.906e+05   1.02e+04     87.332      0.000    8.71e+05    9.11e+05
# Landsize     372.9616     19.109     19.518      0.000     335.501     410.422
# ==============================================================================
# Omnibus:                      799.967   Durbin-Watson:                   1.457
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1224.001
# Skew:                           0.952   Prob(JB):                    1.63e-266
# Kurtosis:                       4.124   Cond. No.                         816.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# Variable:  BuildingArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.392
# Model:                            OLS   Adj. R-squared:                  0.392
# Method:                 Least Squares   F-statistic:                     3877.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:52:48   Log-Likelihood:                -86205.
# No. Observations:                6005   AIC:                         1.724e+05
# Df Residuals:                    6003   BIC:                         1.724e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         3.254e+05   1.27e+04     25.652      0.000    3.01e+05     3.5e+05
# BuildingArea  5345.7152     85.855     62.265      0.000    5177.409    5514.021
# ==============================================================================
# Omnibus:                      921.026   Durbin-Watson:                   1.421
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1990.795
# Skew:                           0.909   Prob(JB):                         0.00
# Kurtosis:                       5.157   Cond. No.                         350.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# Variable:  YearBuilt
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.134
# Model:                            OLS   Adj. R-squared:                  0.134
# Method:                 Least Squares   F-statistic:                     928.1
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):          1.12e-189
# Time:                        23:52:48   Log-Likelihood:                -87270.
# No. Observations:                6005   AIC:                         1.745e+05
# Df Residuals:                    6003   BIC:                         1.746e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.147e+07   3.42e+05     33.503      0.000    1.08e+07    1.21e+07
# YearBuilt  -5309.7615    174.289    -30.465      0.000   -5651.431   -4968.092
# ==============================================================================
# Omnibus:                     1094.107   Durbin-Watson:                   1.497
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1952.132
# Skew:                           1.159   Prob(JB):                         0.00
# Kurtosis:                       4.559   Cond. No.                     1.05e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.05e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# Variable:  Propertycount
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.591
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):              0.207
# Time:                        23:52:49   Log-Likelihood:                -87701.
# No. Observations:                6005   AIC:                         1.754e+05
# Df Residuals:                    6003   BIC:                         1.754e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          1.025e+06   1.48e+04     69.350      0.000    9.96e+05    1.05e+06
# Propertycount     2.3744      1.882      1.261      0.207      -1.316       6.064
# ==============================================================================
# Omnibus:                      942.503   Durbin-Watson:                   1.482
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1474.022
# Skew:                           1.101   Prob(JB):                         0.00
# Kurtosis:                       4.022   Cond. No.                     1.69e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.69e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# Variable:  Lattitude
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.063
# Model:                            OLS   Adj. R-squared:                  0.063
# Method:                 Least Squares   F-statistic:                     402.7
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):           9.50e-87
# Time:                        23:52:49   Log-Likelihood:                -87506.
# No. Observations:                6005   AIC:                         1.750e+05
# Df Residuals:                    6003   BIC:                         1.750e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -7.205e+07   3.64e+06    -19.781      0.000   -7.92e+07   -6.49e+07
# Lattitude  -1.933e+06   9.63e+04    -20.067      0.000   -2.12e+06   -1.74e+06
# ==============================================================================
# Omnibus:                      843.034   Durbin-Watson:                   1.550
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1284.851
# Skew:                           1.004   Prob(JB):                    9.96e-280
# Kurtosis:                       4.048   Cond. No.                     2.07e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.07e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# Variable:  Longtitude
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.057
# Model:                            OLS   Adj. R-squared:                  0.057
# Method:                 Least Squares   F-statistic:                     364.0
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):           7.73e-79
# Time:                        23:52:49   Log-Likelihood:                -87525.
# No. Observations:                6005   AIC:                         1.751e+05
# Df Residuals:                    6003   BIC:                         1.751e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2.011e+08   1.06e+07    -18.981      0.000   -2.22e+08    -1.8e+08
# Longtitude  1.394e+06   7.31e+04     19.080      0.000    1.25e+06    1.54e+06
# ==============================================================================
# Omnibus:                      924.597   Durbin-Watson:                   1.563
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1455.272
# Skew:                           1.071   Prob(JB):                         0.00
# Kurtosis:                       4.107   Cond. No.                     2.30e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.3e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Mejor R-squared: 0.39240185180401554
# Mejor columns: BuildingArea

# %%
#compara 2 variables
variables =['Rooms', 'Distance','Bedroom2', 'Car','Landsize','BuildingArea','YearBuilt','Propertycount','Lattitude','Longtitude']
for col1, col2 in itertools.combinations(variables,2):
  x=df1[[col1,col2]]
  y=df1['Price']
  x2= sm.add_constant(x)
  est =sm.OLS(y,x2)
  est2 = est.fit()
  print("\nColumns: ",col1, "and", col2)
  print(est2.summary())
  best_r2 = 0
for col1, col2 in itertools.combinations(variables,2):
  x=df1[[col1,col2]]
  y=df1['Price']
  x2= sm.add_constant(x)
  est =sm.OLS(y,x2)
  est2 = est.fit()
  r2 = est2.rsquared
  if r2 > best_r2:
    best_r2 = r2
    best_columns = (col1, col2)
  print("\nColumns: ",col1, "and", col2)
  print(est2.summary())

print("mejor R-squared:", best_r2)
print("mejor columns:", best_columns)
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# Columns:  Rooms and Distance
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.402
# Model:                            OLS   Adj. R-squared:                  0.401
# Method:                 Least Squares   F-statistic:                     2014.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:46:46   Log-Likelihood:                -86160.
# No. Observations:                6005   AIC:                         1.723e+05
# Df Residuals:                    6002   BIC:                         1.723e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.761e+05   1.85e+04     14.932      0.000     2.4e+05    3.12e+05
# Rooms        3.86e+05   6170.120     62.560      0.000    3.74e+05    3.98e+05
# Distance   -3.782e+04   1220.739    -30.980      0.000   -4.02e+04   -3.54e+04
# ==============================================================================
# Omnibus:                      937.575   Durbin-Watson:                   1.396
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1699.445
# Skew:                           0.995   Prob(JB):                         0.00
# Kurtosis:                       4.683   Cond. No.                         38.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Columns:  Rooms and Bedroom2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.307
# Model:                            OLS   Adj. R-squared:                  0.307
# Method:                 Least Squares   F-statistic:                     1331.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:46:46   Log-Likelihood:                -86599.
# No. Observations:                6005   AIC:                         1.732e+05
# Df Residuals:                    6002   BIC:                         1.732e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.003e+05   1.91e+04      5.238      0.000    6.27e+04    1.38e+05
# Rooms        2.47e+05   2.27e+04     10.873      0.000    2.02e+05    2.92e+05
# Bedroom2    7.834e+04   2.28e+04      3.437      0.001    3.37e+04    1.23e+05
# ==============================================================================
# Omnibus:                      901.878   Durbin-Watson:                   1.314
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1534.493
# Skew:                           0.993   Prob(JB):                         0.00
# Kurtosis:                       4.480   Cond. No.                         24.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Columns:  Rooms and Car
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.306
# Model:                            OLS   Adj. R-squared:                  0.306
# Method:                 Least Squares   F-statistic:                     1324.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:46:46   Log-Likelihood:                -86604.
# No. Observations:                6005   AIC:                         1.732e+05
# Df Residuals:                    6002   BIC:                         1.732e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.033e+05   1.93e+04      5.348      0.000    6.54e+04    1.41e+05
# Rooms       3.182e+05   6894.885     46.148      0.000    3.05e+05    3.32e+05
# Car         1.047e+04   7680.345      1.364      0.173   -4581.296    2.55e+04
# ==============================================================================
# Omnibus:                      907.059   Durbin-Watson:                   1.313
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1542.868
# Skew:                           0.998   Prob(JB):                         0.00
# Kurtosis:                       4.477   Cond. No.                         12.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Columns:  Rooms and Landsize
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.309
# Model:                            OLS   Adj. R-squared:                  0.309
# Method:                 Least Squares   F-statistic:                     1342.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:46:46   Log-Likelihood:                -86591.
# No. Observations:                6005   AIC:                         1.732e+05
# Df Residuals:                    6002   BIC:                         1.732e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.059e+05    1.9e+04      5.576      0.000    6.87e+04    1.43e+05
# Rooms       3.101e+05   6662.407     46.541      0.000    2.97e+05    3.23e+05
# Landsize      91.0686     17.466      5.214      0.000      56.830     125.307
# ==============================================================================
# Omnibus:                      886.371   Durbin-Watson:                   1.300
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1487.630
# Skew:                           0.985   Prob(JB):                         0.00
# Kurtosis:                       4.437   Cond. No.                     1.86e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.86e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columns:  Rooms and BuildingArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.410
# Model:                            OLS   Adj. R-squared:                  0.410
# Method:                 Least Squares   F-statistic:                     2087.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:46:46   Log-Likelihood:                -86116.
# No. Observations:                6005   AIC:                         1.722e+05
# Df Residuals:                    6002   BIC:                         1.723e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         1.587e+05   1.76e+04      9.009      0.000    1.24e+05    1.93e+05
# Rooms         1.153e+05   8583.414     13.431      0.000    9.85e+04    1.32e+05
# BuildingArea  4095.7600    125.769     32.566      0.000    3849.208    4342.312
# ==============================================================================
# Omnibus:                      830.160   Durbin-Watson:                   1.346
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1585.035
# Skew:                           0.874   Prob(JB):                         0.00
# Kurtosis:                       4.811   Cond. No.                         524.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Columns:  Rooms and YearBuilt
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.416
# Model:                            OLS   Adj. R-squared:                  0.416
# Method:                 Least Squares   F-statistic:                     2141.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:46:46   Log-Likelihood:                -86085.
# No. Observations:                6005   AIC:                         1.722e+05
# Df Residuals:                    6002   BIC:                         1.722e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.627e+06   2.83e+05     34.016      0.000    9.07e+06    1.02e+07
# Rooms       3.101e+05   5754.332     53.892      0.000    2.99e+05    3.21e+05
# YearBuilt  -4831.2105    143.364    -33.699      0.000   -5112.255   -4550.166
# ==============================================================================
# Omnibus:                     1060.671   Durbin-Watson:                   1.380
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2161.909
# Skew:                           1.056   Prob(JB):                         0.00
# Kurtosis:                       5.045   Cond. No.                     1.06e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.06e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columns:  Rooms and Propertycount
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.313
# Model:                            OLS   Adj. R-squared:                  0.313
# Method:                 Least Squares   F-statistic:                     1369.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:46:46   Log-Likelihood:                -86573.
# No. Observations:                6005   AIC:                         1.732e+05
# Df Residuals:                    6002   BIC:                         1.732e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          1401.2418   2.31e+04      0.061      0.952   -4.38e+04    4.66e+04
# Rooms          3.285e+05   6278.862     52.311      0.000    3.16e+05    3.41e+05
# Propertycount    12.6686      1.573      8.056      0.000       9.586      15.751
# ==============================================================================
# Omnibus:                      920.405   Durbin-Watson:                   1.326
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1594.232
# Skew:                           1.001   Prob(JB):                         0.00
# Kurtosis:                       4.536   Cond. No.                     3.26e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.26e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columns:  Rooms and Lattitude
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.379
# Model:                            OLS   Adj. R-squared:                  0.379
# Method:                 Least Squares   F-statistic:                     1834.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:46:46   Log-Likelihood:                -86269.
# No. Observations:                6005   AIC:                         1.725e+05
# Df Residuals:                    6002   BIC:                         1.726e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -7.898e+07   2.97e+06    -26.618      0.000   -8.48e+07   -7.32e+07
# Rooms       3.279e+05   5926.293     55.325      0.000    3.16e+05    3.39e+05
# Lattitude  -2.091e+06   7.85e+04    -26.655      0.000   -2.25e+06   -1.94e+06
# ==============================================================================
# Omnibus:                      929.420   Durbin-Watson:                   1.410
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1689.184
# Skew:                           0.986   Prob(JB):                         0.00
# Kurtosis:                       4.692   Cond. No.                     2.08e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.08e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columns:  Rooms and Longtitude
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.338
# Model:                            OLS   Adj. R-squared:                  0.337
# Method:                 Least Squares   F-statistic:                     1529.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:46:46   Log-Likelihood:                -86465.
# No. Observations:                6005   AIC:                         1.729e+05
# Df Residuals:                    6002   BIC:                         1.730e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.511e+08   8.93e+06    -16.913      0.000   -1.69e+08   -1.34e+08
# Rooms       3.104e+05   6158.148     50.398      0.000    2.98e+05    3.22e+05
# Longtitude  1.043e+06   6.16e+04     16.925      0.000    9.22e+05    1.16e+06
# ==============================================================================
# Omnibus:                      954.278   Durbin-Watson:                   1.375
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1699.875
# Skew:                           1.020   Prob(JB):                         0.00
# Kurtosis:                       4.623   Cond. No.                     2.32e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.32e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columns:  Distance and Bedroom2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.389
# Model:                            OLS   Adj. R-squared:                  0.389
# Method:                 Least Squares   F-statistic:                     1911.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:46:46   Log-Likelihood:                -86222.
# No. Observations:                6005   AIC:                         1.724e+05
# Df Residuals:                    6002   BIC:                         1.725e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.982e+05   1.86e+04     16.049      0.000    2.62e+05    3.35e+05
# Distance   -3.785e+04   1235.877    -30.628      0.000   -4.03e+04   -3.54e+04
# Bedroom2    3.817e+05   6265.753     60.918      0.000    3.69e+05    3.94e+05
# ==============================================================================
# Omnibus:                      936.948   Durbin-Watson:                   1.418
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1687.115
# Skew:                           0.998   Prob(JB):                         0.00
# Kurtosis:                       4.662   Cond. No.                         38.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Columns:  Distance and Car
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.098
# Model:                            OLS   Adj. R-squared:                  0.098
# Method:                 Least Squares   F-statistic:                     327.1
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):          1.41e-135
# Time:                        23:46:46   Log-Likelihood:                -87391.
# No. Observations:                6005   AIC:                         1.748e+05
# Df Residuals:                    6002   BIC:                         1.748e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.574e+05   1.69e+04     56.701      0.000    9.24e+05    9.91e+05
# Distance   -2.384e+04   1491.701    -15.983      0.000   -2.68e+04   -2.09e+04
# Car          2.02e+05   8398.589     24.051      0.000    1.86e+05    2.18e+05
# ==============================================================================
# Omnibus:                      840.363   Durbin-Watson:                   1.494
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1264.104
# Skew:                           1.014   Prob(JB):                    3.19e-275
# Kurtosis:                       3.969   Cond. No.                         28.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Columns:  Distance and Landsize
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.096
# Model:                            OLS   Adj. R-squared:                  0.096
# Method:                 Least Squares   F-statistic:                     319.3
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):          1.60e-132
# Time:                        23:46:46   Log-Likelihood:                -87398.
# No. Observations:                6005   AIC:                         1.748e+05
# Df Residuals:                    6002   BIC:                         1.748e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.069e+06   1.52e+04     70.337      0.000    1.04e+06     1.1e+06
# Distance   -2.314e+04   1485.963    -15.570      0.000    -2.6e+04   -2.02e+04
# Landsize     467.2065     19.689     23.729      0.000     428.608     505.805
# ==============================================================================
# Omnibus:                      619.824   Durbin-Watson:                   1.477
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1015.854
# Skew:                           0.738   Prob(JB):                    2.57e-221
# Kurtosis:                       4.373   Cond. No.                     1.24e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.24e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columns:  Distance and BuildingArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.469
# Model:                            OLS   Adj. R-squared:                  0.469
# Method:                 Least Squares   F-statistic:                     2647.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:46:46   Log-Likelihood:                -85802.
# No. Observations:                6005   AIC:                         1.716e+05
# Df Residuals:                    6002   BIC:                         1.716e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         5.495e+05   1.41e+04     38.955      0.000    5.22e+05    5.77e+05
# Distance     -3.293e+04   1121.464    -29.360      0.000   -3.51e+04   -3.07e+04
# BuildingArea  5969.8207     83.056     71.877      0.000    5807.002    6132.640
# ==============================================================================
# Omnibus:                     1002.196   Durbin-Watson:                   1.517
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2551.382
# Skew:                           0.922   Prob(JB):                         0.00
# Kurtosis:                       5.607   Cond. No.                         417.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Columns:  Distance and YearBuilt
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.134
# Model:                            OLS   Adj. R-squared:                  0.134
# Method:                 Least Squares   F-statistic:                     464.1
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):          3.81e-188
# Time:                        23:46:46   Log-Likelihood:                -87270.
# No. Observations:                6005   AIC:                         1.745e+05
# Df Residuals:                    6002   BIC:                         1.746e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.142e+07   3.53e+05     32.397      0.000    1.07e+07    1.21e+07
# Distance    -682.8205   1440.371     -0.474      0.635   -3506.465    2140.824
# YearBuilt  -5285.9721    181.380    -29.143      0.000   -5641.543   -4930.401
# ==============================================================================
# Omnibus:                     1090.561   Durbin-Watson:                   1.496
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1942.480
# Skew:                           1.156   Prob(JB):                         0.00
# Kurtosis:                       4.555   Cond. No.                     1.08e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.08e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columns:  Distance and Propertycount
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     34.64
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):           1.10e-15
# Time:                        23:46:46   Log-Likelihood:                -87667.
# No. Observations:                6005   AIC:                         1.753e+05
# Df Residuals:                    6002   BIC:                         1.754e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          1.162e+06   2.22e+04     52.253      0.000    1.12e+06    1.21e+06
# Distance      -1.241e+04   1508.062     -8.226      0.000   -1.54e+04   -9448.930
# Propertycount    -0.7028      1.909     -0.368      0.713      -4.445       3.039
# ==============================================================================
# Omnibus:                      891.395   Durbin-Watson:                   1.480
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1367.099
# Skew:                           1.058   Prob(JB):                    1.37e-297
# Kurtosis:                       3.995   Cond. No.                     2.56e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.56e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columns:  Distance and Lattitude
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.078
# Model:                            OLS   Adj. R-squared:                  0.077
# Method:                 Least Squares   F-statistic:                     253.2
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):          2.76e-106
# Time:                        23:46:46   Log-Likelihood:                -87458.
# No. Observations:                6005   AIC:                         1.749e+05
# Df Residuals:                    6002   BIC:                         1.749e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -7.409e+07   3.62e+06    -20.470      0.000   -8.12e+07    -6.7e+07
# Distance   -1.411e+04   1430.960     -9.859      0.000   -1.69e+04   -1.13e+04
# Lattitude  -1.991e+06   9.58e+04    -20.790      0.000   -2.18e+06    -1.8e+06
# ==============================================================================
# Omnibus:                      746.982   Durbin-Watson:                   1.550
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1096.109
# Skew:                           0.925   Prob(JB):                    9.62e-239
# Kurtosis:                       3.980   Cond. No.                     2.14e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.14e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columns:  Distance and Longtitude
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.096
# Model:                            OLS   Adj. R-squared:                  0.095
# Method:                 Least Squares   F-statistic:                     317.1
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):          1.26e-131
# Time:                        23:46:46   Log-Likelihood:                -87400.
# No. Observations:                6005   AIC:                         1.748e+05
# Df Residuals:                    6002   BIC:                         1.748e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2.583e+08    1.1e+07    -23.529      0.000    -2.8e+08   -2.37e+08
# Distance   -2.389e+04   1497.200    -15.960      0.000   -2.68e+04    -2.1e+04
# Longtitude   1.79e+06   7.57e+04     23.634      0.000    1.64e+06    1.94e+06
# ==============================================================================
# Omnibus:                      787.948   Durbin-Watson:                   1.583
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1187.799
# Skew:                           0.950   Prob(JB):                    1.18e-258
# Kurtosis:                       4.066   Cond. No.                     2.44e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.44e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columns:  Bedroom2 and Car
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.294
# Model:                            OLS   Adj. R-squared:                  0.294
# Method:                 Least Squares   F-statistic:                     1250.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:46:46   Log-Likelihood:                -86656.
# No. Observations:                6005   AIC:                         1.733e+05
# Df Residuals:                    6002   BIC:                         1.733e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.257e+05   1.94e+04      6.483      0.000    8.77e+04    1.64e+05
# Bedroom2    3.114e+05   6980.035     44.609      0.000    2.98e+05    3.25e+05
# Car         1.372e+04   7751.475      1.769      0.077   -1479.982    2.89e+04
# ==============================================================================
# Omnibus:                      910.038   Durbin-Watson:                   1.329
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1549.040
# Skew:                           1.001   Prob(JB):                         0.00
# Kurtosis:                       4.479   Cond. No.                         12.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Columns:  Bedroom2 and Landsize
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.297
# Model:                            OLS   Adj. R-squared:                  0.297
# Method:                 Least Squares   F-statistic:                     1271.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:46:46   Log-Likelihood:                -86641.
# No. Observations:                6005   AIC:                         1.733e+05
# Df Residuals:                    6002   BIC:                         1.733e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        1.29e+05   1.91e+04      6.768      0.000    9.16e+04    1.66e+05
# Bedroom2    3.033e+05   6729.413     45.073      0.000     2.9e+05    3.17e+05
# Landsize     100.7851     17.587      5.731      0.000      66.307     135.263
# ==============================================================================
# Omnibus:                      887.266   Durbin-Watson:                   1.315
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1488.647
# Skew:                           0.986   Prob(JB):                         0.00
# Kurtosis:                       4.436   Cond. No.                     1.85e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.85e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columns:  Bedroom2 and BuildingArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.408
# Model:                            OLS   Adj. R-squared:                  0.408
# Method:                 Least Squares   F-statistic:                     2070.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:46:46   Log-Likelihood:                -86126.
# No. Observations:                6005   AIC:                         1.723e+05
# Df Residuals:                    6002   BIC:                         1.723e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           1.7e+05   1.75e+04      9.702      0.000    1.36e+05    2.04e+05
# Bedroom2      1.071e+05   8449.389     12.674      0.000    9.05e+04    1.24e+05
# BuildingArea  4208.3016    123.427     34.095      0.000    3966.340    4450.264
# ==============================================================================
# Omnibus:                      822.019   Durbin-Watson:                   1.353
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1581.940
# Skew:                           0.864   Prob(JB):                         0.00
# Kurtosis:                       4.827   Cond. No.                         520.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Columns:  Bedroom2 and YearBuilt
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.408
# Model:                            OLS   Adj. R-squared:                  0.408
# Method:                 Least Squares   F-statistic:                     2069.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:46:46   Log-Likelihood:                -86127.
# No. Observations:                6005   AIC:                         1.723e+05
# Df Residuals:                    6002   BIC:                         1.723e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.812e+06   2.85e+05     34.470      0.000    9.25e+06    1.04e+07
# Bedroom2    3.063e+05   5809.109     52.730      0.000    2.95e+05    3.18e+05
# YearBuilt  -4916.1571    144.287    -34.072      0.000   -5199.012   -4633.302
# ==============================================================================
# Omnibus:                     1069.289   Durbin-Watson:                   1.399
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2157.184
# Skew:                           1.068   Prob(JB):                         0.00
# Kurtosis:                       5.014   Cond. No.                     1.06e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.06e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# Columns:  Bedroom2 and Propertycount
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.301
# Model:                            OLS   Adj. R-squared:                  0.301
# Method:                 Least Squares   F-statistic:                     1292.
# ...
# strong multicollinearity or other numerical problems.
#
# Columns:  BuildingArea and Longtitude
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.418
# Model:                            OLS   Adj. R-squared:                  0.417
# Method:                 Least Squares   F-statistic:                     2152.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:46:47   Log-Likelihood:                -86078.
# No. Observations:                6005   AIC:                         1.722e+05
# Df Residuals:                    6002   BIC:                         1.722e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         -1.35e+08    8.4e+06    -16.084      0.000   -1.51e+08   -1.19e+08
# BuildingArea  5167.5346     84.784     60.949      0.000    5001.327    5333.742
# Longtitude    9.337e+05   5.79e+04     16.123      0.000     8.2e+05    1.05e+06
# ==============================================================================
# Omnibus:                      964.397   Durbin-Watson:                   1.469
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2113.569
# Skew:                           0.942   Prob(JB):                         0.00
# Kurtosis:                       5.214   Cond. No.                     3.23e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.23e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columns:  YearBuilt and Propertycount
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.134
# Model:                            OLS   Adj. R-squared:                  0.134
# Method:                 Least Squares   F-statistic:                     464.0
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):          4.24e-188
# Time:                        23:46:47   Log-Likelihood:                -87270.
# No. Observations:                6005   AIC:                         1.745e+05
# Df Residuals:                    6002   BIC:                         1.746e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          1.147e+07   3.43e+05     33.392      0.000    1.08e+07    1.21e+07
# YearBuilt     -5310.6882    174.505    -30.433      0.000   -5652.781   -4968.595
# Propertycount    -0.1936      1.754     -0.110      0.912      -3.632       3.245
# ==============================================================================
# Omnibus:                     1094.428   Durbin-Watson:                   1.497
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1953.014
# Skew:                           1.159   Prob(JB):                         0.00
# Kurtosis:                       4.560   Cond. No.                     4.32e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.32e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columns:  YearBuilt and Lattitude
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.187
# Model:                            OLS   Adj. R-squared:                  0.187
# Method:                 Least Squares   F-statistic:                     690.4
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):          1.32e-270
# Time:                        23:46:47   Log-Likelihood:                -87080.
# No. Observations:                6005   AIC:                         1.742e+05
# Df Residuals:                    6002   BIC:                         1.742e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5.621e+07   3.43e+06    -16.373      0.000   -6.29e+07   -4.95e+07
# YearBuilt  -5121.2620    169.141    -30.278      0.000   -5452.838   -4789.686
# Lattitude   -1.78e+06   8.99e+04    -19.806      0.000   -1.96e+06    -1.6e+06
# ==============================================================================
# Omnibus:                      982.663   Durbin-Watson:                   1.563
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1727.510
# Skew:                           1.055   Prob(JB):                         0.00
# Kurtosis:                       4.567   Cond. No.                     1.09e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.09e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columns:  YearBuilt and Longtitude
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.193
# Model:                            OLS   Adj. R-squared:                  0.193
# Method:                 Least Squares   F-statistic:                     718.8
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):          1.45e-280
# Time:                        23:46:47   Log-Likelihood:                -87057.
# No. Observations:                6005   AIC:                         1.741e+05
# Df Residuals:                    6002   BIC:                         1.741e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.943e+08    9.8e+06    -19.825      0.000   -2.14e+08   -1.75e+08
# YearBuilt  -5352.4772    168.241    -31.814      0.000   -5682.290   -5022.664
# Longtitude   1.42e+06   6.76e+04     21.007      0.000    1.29e+06    1.55e+06
# ==============================================================================
# Omnibus:                     1072.697   Durbin-Watson:                   1.600
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1963.439
# Skew:                           1.121   Prob(JB):                         0.00
# Kurtosis:                       4.680   Cond. No.                     3.12e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.12e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columns:  Propertycount and Lattitude
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.063
# Model:                            OLS   Adj. R-squared:                  0.063
# Method:                 Least Squares   F-statistic:                     201.3
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):           2.38e-85
# Time:                        23:46:47   Log-Likelihood:                -87506.
# No. Observations:                6005   AIC:                         1.750e+05
# Df Residuals:                    6002   BIC:                         1.750e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -7.203e+07   3.65e+06    -19.742      0.000   -7.92e+07   -6.49e+07
# Propertycount     0.2056      1.826      0.113      0.910      -3.374       3.785
# Lattitude     -1.933e+06   9.65e+04    -20.023      0.000   -2.12e+06   -1.74e+06
# ==============================================================================
# Omnibus:                      842.737   Durbin-Watson:                   1.550
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1284.267
# Skew:                           1.004   Prob(JB):                    1.33e-279
# Kurtosis:                       4.048   Cond. No.                     4.30e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.3e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columns:  Propertycount and Longtitude
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.057
# Model:                            OLS   Adj. R-squared:                  0.057
# Method:                 Least Squares   F-statistic:                     182.3
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):           1.39e-77
# Time:                        23:46:47   Log-Likelihood:                -87524.
# No. Observations:                6005   AIC:                         1.751e+05
# Df Residuals:                    6002   BIC:                         1.751e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -2.019e+08   1.07e+07    -18.954      0.000   -2.23e+08   -1.81e+08
# Propertycount    -1.3990      1.839     -0.761      0.447      -5.004       2.206
# Longtitude       1.4e+06   7.35e+04     19.050      0.000    1.26e+06    1.54e+06
# ==============================================================================
# Omnibus:                      926.772   Durbin-Watson:                   1.564
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1460.264
# Skew:                           1.073   Prob(JB):                         0.00
# Kurtosis:                       4.110   Cond. No.                     1.25e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.25e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columns:  Lattitude and Longtitude
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.089
# Model:                            OLS   Adj. R-squared:                  0.089
# Method:                 Least Squares   F-statistic:                     292.7
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):          4.92e-122
# Time:                        23:46:47   Log-Likelihood:                -87422.
# No. Observations:                6005   AIC:                         1.748e+05
# Df Residuals:                    6002   BIC:                         1.749e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          -2e+08   1.04e+07    -19.206      0.000    -2.2e+08    -1.8e+08
# Lattitude  -1.466e+06   1.01e+05    -14.451      0.000   -1.67e+06   -1.27e+06
# Longtitude  1.004e+06   7.67e+04     13.090      0.000    8.54e+05    1.15e+06
# ==============================================================================
# Omnibus:                      839.497   Durbin-Watson:                   1.598
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1288.964
# Skew:                           0.994   Prob(JB):                    1.27e-280
# Kurtosis:                       4.095   Cond. No.                     2.38e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.38e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# mejor R-squared: 0.5364135126225607
# mejor columns: ('BuildingArea', 'YearBuilt')
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
#compara 3 variables
variables =['Rooms', 'Distance','Bedroom2', 'Car','Landsize','BuildingArea','YearBuilt','Propertycount','Lattitude','Longtitude']
best_r2 = 0
for col1, col2, col3 in itertools.combinations(variables,3):
  x=df1[[col1,col2,col3]]
  y=df1['Price']
  x2= sm.add_constant(x)
  est =sm.OLS(y,x2)
  est2 = est.fit()
  r2 = est2.rsquared
  if r2 > best_r2:
    best_r2 = r2
    best_columns = (col1, col2, col3)
  print("\nColumnas: ",col1, ",", col2, "y", col3)
  print(est2.summary())

print("Mejor R-squared:", best_r2)
print("Mejor columnas:", best_columns)
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# Columnas:  Rooms , Distance y Bedroom2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.405
# Model:                            OLS   Adj. R-squared:                  0.405
# Method:                 Least Squares   F-statistic:                     1362.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:49:01   Log-Likelihood:                -86142.
# No. Observations:                6005   AIC:                         1.723e+05
# Df Residuals:                    6001   BIC:                         1.723e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.663e+05   1.85e+04     14.387      0.000     2.3e+05    3.03e+05
# Rooms       2.672e+05   2.11e+04     12.681      0.000    2.26e+05    3.08e+05
# Distance   -3.832e+04   1220.311    -31.404      0.000   -4.07e+04   -3.59e+04
# Bedroom2    1.249e+05   2.12e+04      5.898      0.000    8.34e+04    1.66e+05
# ==============================================================================
# Omnibus:                      921.205   Durbin-Watson:                   1.398
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1652.550
# Skew:                           0.985   Prob(JB):                         0.00
# Kurtosis:                       4.651   Cond. No.                         62.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Columnas:  Rooms , Distance y Car
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.408
# Model:                            OLS   Adj. R-squared:                  0.408
# Method:                 Least Squares   F-statistic:                     1381.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:49:01   Log-Likelihood:                -86125.
# No. Observations:                6005   AIC:                         1.723e+05
# Df Residuals:                    6001   BIC:                         1.723e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         2.6e+05   1.85e+04     14.063      0.000    2.24e+05    2.96e+05
# Rooms       3.671e+05   6545.809     56.081      0.000    3.54e+05     3.8e+05
# Distance   -4.001e+04   1242.304    -32.204      0.000   -4.24e+04   -3.76e+04
# Car         6.016e+04   7258.416      8.289      0.000    4.59e+04    7.44e+04
# ==============================================================================
# Omnibus:                      895.864   Durbin-Watson:                   1.398
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1587.340
# Skew:                           0.966   Prob(JB):                         0.00
# Kurtosis:                       4.615   Cond. No.                         39.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Columnas:  Rooms , Distance y Landsize
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.417
# Model:                            OLS   Adj. R-squared:                  0.417
# Method:                 Least Squares   F-statistic:                     1433.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:49:01   Log-Likelihood:                -86079.
# No. Observations:                6005   AIC:                         1.722e+05
# Df Residuals:                    6001   BIC:                         1.722e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        2.87e+05   1.83e+04     15.714      0.000    2.51e+05    3.23e+05
# Rooms        3.64e+05   6327.040     57.530      0.000    3.52e+05    3.76e+05
# Distance   -4.124e+04   1233.855    -33.420      0.000   -4.37e+04   -3.88e+04
# Landsize     210.0244     16.428     12.784      0.000     177.819     242.230
# ==============================================================================
# Omnibus:                      827.639   Durbin-Watson:                   1.388
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1422.739
# Skew:                           0.915   Prob(JB):                    1.14e-309
# Kurtosis:                       4.528   Cond. No.                     1.92e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.92e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columnas:  Rooms , Distance y BuildingArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.509
# Model:                            OLS   Adj. R-squared:                  0.508
# Method:                 Least Squares   F-statistic:                     2070.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:49:01   Log-Likelihood:                -85568.
# No. Observations:                6005   AIC:                         1.711e+05
# Df Residuals:                    6001   BIC:                         1.712e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         3.301e+05   1.68e+04     19.622      0.000    2.97e+05    3.63e+05
# Rooms         1.773e+05   8036.922     22.066      0.000    1.62e+05    1.93e+05
# Distance     -3.836e+04   1106.436    -34.673      0.000   -4.05e+04   -3.62e+04
# BuildingArea  4150.0639    114.815     36.146      0.000    3924.986    4375.142
# ==============================================================================
# Omnibus:                      880.433   Durbin-Watson:                   1.444
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1804.800
# Skew:                           0.892   Prob(JB):                         0.00
# Kurtosis:                       5.007   Cond. No.                         540.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Columnas:  Rooms , Distance y YearBuilt
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.463
# Model:                            OLS   Adj. R-squared:                  0.462
# Method:                 Least Squares   F-statistic:                     1723.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:49:01   Log-Likelihood:                -85836.
# No. Observations:                6005   AIC:                         1.717e+05
# Df Residuals:                    6001   BIC:                         1.717e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       7.695e+06   2.85e+05     27.046      0.000    7.14e+06    8.25e+06
# Rooms       3.596e+05   5933.932     60.596      0.000    3.48e+05    3.71e+05
# Distance   -2.775e+04   1219.352    -22.757      0.000   -3.01e+04   -2.54e+04
# YearBuilt  -3788.1347    144.999    -26.125      0.000   -4072.384   -3503.885
# ==============================================================================
# Omnibus:                     1053.604   Durbin-Watson:                   1.396
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2219.622
# Skew:                           1.036   Prob(JB):                         0.00
# Kurtosis:                       5.140   Cond. No.                     1.11e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.11e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columnas:  Rooms , Distance y Propertycount
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.403
# Model:                            OLS   Adj. R-squared:                  0.403
# Method:                 Least Squares   F-statistic:                     1350.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:49:01   Log-Likelihood:                -86153.
# No. Observations:                6005   AIC:                         1.723e+05
# Df Residuals:                    6001   BIC:                         1.723e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          2.282e+05   2.28e+04     10.002      0.000    1.83e+05    2.73e+05
# Rooms          3.874e+05   6176.951     62.722      0.000    3.75e+05       4e+05
# Distance      -3.709e+04   1236.456    -29.997      0.000   -3.95e+04   -3.47e+04
# Propertycount     5.3166      1.487      3.576      0.000       2.402       8.231
# ==============================================================================
# Omnibus:                      936.902   Durbin-Watson:                   1.398
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1698.024
# Skew:                           0.995   Prob(JB):                         0.00
# Kurtosis:                       4.682   Cond. No.                     3.43e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.43e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columnas:  Rooms , Distance y Lattitude
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.489
# Model:                            OLS   Adj. R-squared:                  0.489
# Method:                 Least Squares   F-statistic:                     1916.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:49:02   Log-Likelihood:                -85685.
# No. Observations:                6005   AIC:                         1.714e+05
# Df Residuals:                    6001   BIC:                         1.714e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -8.632e+07    2.7e+06    -31.972      0.000   -9.16e+07    -8.1e+07
# Rooms       3.971e+05   5711.649     69.517      0.000    3.86e+05    4.08e+05
# Distance   -4.063e+04   1131.381    -35.915      0.000   -4.29e+04   -3.84e+04
# Lattitude   -2.29e+06   7.14e+04    -32.075      0.000   -2.43e+06   -2.15e+06
# ==============================================================================
# Omnibus:                      902.979   Durbin-Watson:                   1.548
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1742.145
# Skew:                           0.936   Prob(JB):                         0.00
# Kurtosis:                       4.860   Cond. No.                     2.15e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.15e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columnas:  Rooms , Distance y Longtitude
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.484
# Model:                            OLS   Adj. R-squared:                  0.484
# Method:                 Least Squares   F-statistic:                     1879.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:49:02   Log-Likelihood:                -85712.
# No. Observations:                6005   AIC:                         1.714e+05
# Df Residuals:                    6001   BIC:                         1.715e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2.571e+08   8.29e+06    -31.013      0.000   -2.73e+08   -2.41e+08
# Rooms       3.853e+05   5727.804     67.274      0.000    3.74e+05    3.97e+05
# Distance   -4.928e+04   1191.828    -41.347      0.000   -5.16e+04   -4.69e+04
# Longtitude  1.776e+06   5.72e+04     31.046      0.000    1.66e+06    1.89e+06
# ==============================================================================
# Omnibus:                     1020.816   Durbin-Watson:                   1.542
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2099.961
# Skew:                           1.016   Prob(JB):                         0.00
# Kurtosis:                       5.065   Cond. No.                     2.44e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.44e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columnas:  Rooms , Bedroom2 y Car
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.307
# Model:                            OLS   Adj. R-squared:                  0.307
# Method:                 Least Squares   F-statistic:                     887.9
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:49:02   Log-Likelihood:                -86598.
# No. Observations:                6005   AIC:                         1.732e+05
# Df Residuals:                    6001   BIC:                         1.732e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.669e+04   1.94e+04      4.985      0.000    5.87e+04    1.35e+05
# Rooms       2.455e+05   2.28e+04     10.785      0.000    2.01e+05     2.9e+05
# Bedroom2    7.656e+04   2.28e+04      3.351      0.001    3.18e+04    1.21e+05
# Car         8694.5850   7692.174      1.130      0.258   -6384.841    2.38e+04
# ==============================================================================
# Omnibus:                      897.688   Durbin-Watson:                   1.312
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1522.195
# Skew:                           0.990   Prob(JB):                         0.00
# Kurtosis:                       4.470   Cond. No.                         25.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Columnas:  Rooms , Bedroom2 y Landsize
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.310
# Model:                            OLS   Adj. R-squared:                  0.310
# Method:                 Least Squares   F-statistic:                     899.7
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:49:02   Log-Likelihood:                -86586.
# No. Observations:                6005   AIC:                         1.732e+05
# Df Residuals:                    6001   BIC:                         1.732e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.886e+04   1.91e+04      5.175      0.000    6.14e+04    1.36e+05
# Rooms       2.396e+05   2.27e+04     10.544      0.000    1.95e+05    2.84e+05
# Bedroom2    7.387e+04   2.28e+04      3.246      0.001    2.93e+04    1.18e+05
# Landsize      88.8817     17.465      5.089      0.000      54.645     123.119
# ==============================================================================
# Omnibus:                      877.392   Durbin-Watson:                   1.299
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1468.183
# Skew:                           0.978   Prob(JB):                         0.00
# Kurtosis:                       4.430   Cond. No.                     2.97e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.97e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columnas:  Rooms , Bedroom2 y BuildingArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.410
# Model:                            OLS   Adj. R-squared:                  0.410
# Method:                 Least Squares   F-statistic:                     1391.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:49:02   Log-Likelihood:                -86116.
# No. Observations:                6005   AIC:                         1.722e+05
# Df Residuals:                    6001   BIC:                         1.723e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         1.566e+05   1.77e+04      8.825      0.000    1.22e+05    1.91e+05
# Rooms         9.646e+04   2.15e+04      4.492      0.000    5.44e+04    1.39e+05
# Bedroom2      2.018e+04   2.11e+04      0.956      0.339   -2.12e+04    6.16e+04
# BuildingArea  4085.4842    126.228     32.366      0.000    3838.032    4332.937
# ==============================================================================
# Omnibus:                      826.204   Durbin-Watson:                   1.345
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1575.232
# Skew:                           0.871   Prob(JB):                         0.00
# Kurtosis:                       4.806   Cond. No.                         825.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Columnas:  Rooms , Bedroom2 y YearBuilt
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.418
# Model:                            OLS   Adj. R-squared:                  0.418
# Method:                 Least Squares   F-statistic:                     1440.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:49:02   Log-Likelihood:                -86074.
# No. Observations:                6005   AIC:                         1.722e+05
# Df Residuals:                    6001   BIC:                         1.722e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.655e+06   2.83e+05     34.168      0.000     9.1e+06    1.02e+07
# Rooms       2.157e+05   2.08e+04     10.351      0.000    1.75e+05    2.57e+05
# Bedroom2    9.845e+04   2.09e+04      4.713      0.000    5.75e+04    1.39e+05
# YearBuilt  -4850.3850    143.169    -33.879      0.000   -5131.048   -4569.722
# ==============================================================================
# Omnibus:                     1050.063   Durbin-Watson:                   1.381
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2121.317
# Skew:                           1.050   Prob(JB):                         0.00
# Kurtosis:                       5.017   Cond. No.                     1.06e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.06e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columnas:  Rooms , Bedroom2 y Propertycount
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.315
# Model:                            OLS   Adj. R-squared:                  0.314
# Method:                 Least Squares   F-statistic:                     919.2
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:49:02   Log-Likelihood:                -86566.
# No. Observations:                6005   AIC:                         1.731e+05
# Df Residuals:                    6001   BIC:                         1.732e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -7555.8365   2.32e+04     -0.326      0.745    -5.3e+04    3.79e+04
# Rooms          2.496e+05   2.26e+04     11.043      0.000    2.05e+05    2.94e+05
# Bedroom2       8.236e+04   2.27e+04      3.633      0.000    3.79e+04    1.27e+05
# Propertycount    12.7929      1.571      8.142      0.000       9.713      15.873
# ==============================================================================
# Omnibus:                      909.602   Durbin-Watson:                   1.325
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1569.325
# Skew:                           0.993   Prob(JB):                         0.00
# Kurtosis:                       4.526   Cond. No.                     4.37e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.37e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columnas:  Rooms , Bedroom2 y Lattitude
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.381
# Model:                            OLS   Adj. R-squared:                  0.381
# Method:                 Least Squares   F-statistic:                     1231.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:49:02   Log-Likelihood:                -86261.
# No. Observations:                6005   AIC:                         1.725e+05
# Df Residuals:                    6001   BIC:                         1.726e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -7.916e+07   2.96e+06    -26.709      0.000    -8.5e+07   -7.33e+07
# Rooms       2.449e+05   2.15e+04     11.400      0.000    2.03e+05    2.87e+05
# Bedroom2    8.663e+04   2.15e+04      4.021      0.000    4.44e+04    1.29e+05
# Lattitude  -2.096e+06   7.84e+04    -26.744      0.000   -2.25e+06   -1.94e+06
# ==============================================================================
# Omnibus:                      920.845   Durbin-Watson:                   1.410
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1672.859
# Skew:                           0.978   Prob(JB):                         0.00
# Kurtosis:                       4.691   Cond. No.                     2.08e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.08e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columnas:  Rooms , Bedroom2 y Longtitude
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.339
# Model:                            OLS   Adj. R-squared:                  0.338
# Method:                 Least Squares   F-statistic:                     1024.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:49:02   Log-Likelihood:                -86460.
# No. Observations:                6005   AIC:                         1.729e+05
# Df Residuals:                    6001   BIC:                         1.730e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.504e+08   8.93e+06    -16.846      0.000   -1.68e+08   -1.33e+08
# Rooms        2.44e+05   2.22e+04     10.990      0.000       2e+05    2.88e+05
# Bedroom2    6.927e+04   2.23e+04      3.109      0.002    2.56e+04    1.13e+05
# Longtitude  1.039e+06   6.16e+04     16.857      0.000    9.18e+05    1.16e+06
# ==============================================================================
# Omnibus:                      945.073   Durbin-Watson:                   1.373
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1678.116
# Skew:                           1.012   Prob(JB):                         0.00
# Kurtosis:                       4.614   Cond. No.                     2.32e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.32e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columnas:  Rooms , Car y Landsize
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.309
# Model:                            OLS   Adj. R-squared:                  0.309
# Method:                 Least Squares   F-statistic:                     894.8
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:49:02   Log-Likelihood:                -86591.
# No. Observations:                6005   AIC:                         1.732e+05
# Df Residuals:                    6001   BIC:                         1.732e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.042e+05   1.93e+04      5.404      0.000    6.64e+04    1.42e+05
# Rooms       3.087e+05   7130.484     43.296      0.000    2.95e+05    3.23e+05
# Car         4133.1186   7766.464      0.532      0.595   -1.11e+04    1.94e+04
# Landsize      89.5485     17.699      5.060      0.000      54.853     124.244
# ==============================================================================
# Omnibus:                      884.958   Durbin-Watson:                   1.300
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1483.342
# Skew:                           0.984   Prob(JB):                         0.00
# Kurtosis:                       4.433   Cond. No.                     1.88e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.88e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columnas:  Rooms , Car y BuildingArea
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.411
# Model:                            OLS   Adj. R-squared:                  0.411
# Method:                 Least Squares   F-statistic:                     1396.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:49:02   Log-Likelihood:                -86112.
# No. Observations:                6005   AIC:                         1.722e+05
# Df Residuals:                    6001   BIC:                         1.723e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         1.684e+05   1.79e+04      9.403      0.000    1.33e+05    2.03e+05
# Rooms         1.207e+05   8768.166     13.761      0.000    1.03e+05    1.38e+05
# Car          -2.111e+04   7142.437     -2.955      0.003   -3.51e+04   -7103.627
# BuildingArea  4146.4645    126.854     32.687      0.000    3897.785    4395.144
# ==============================================================================
# Omnibus:                      842.128   Durbin-Watson:                   1.353
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1632.048
# Skew:                           0.879   Prob(JB):                         0.00
# Kurtosis:                       4.853   Cond. No.                         530.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Columnas:  Rooms , Car y YearBuilt
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.423
# Model:                            OLS   Adj. R-squared:                  0.423
# Method:                 Least Squares   F-statistic:                     1468.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:49:02   Log-Likelihood:                -86049.
# No. Observations:                6005   AIC:                         1.721e+05
# Df Residuals:                    6001   BIC:                         1.721e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.009e+07   2.87e+05     35.205      0.000    9.53e+06    1.07e+07
# Rooms       2.867e+05   6350.879     45.146      0.000    2.74e+05    2.99e+05
# Car         6.063e+04   7148.577      8.481      0.000    4.66e+04    7.46e+04
# YearBuilt  -5079.1660    145.492    -34.910      0.000   -5364.383   -4793.949
# ==============================================================================
# Omnibus:                     1019.875   Durbin-Watson:                   1.379
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2046.799
# Skew:                           1.026   Prob(JB):                         0.00
# Kurtosis:                       4.993   Cond. No.                     1.08e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.08e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columnas:  Rooms , Car y Propertycount
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.314
# Model:                            OLS   Adj. R-squared:                  0.313
# Method:                 Least Squares   F-statistic:                     914.1
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:49:02   Log-Likelihood:                -86571.
# No. Observations:                6005   AIC:                         1.732e+05
# Df Residuals:                    6001   BIC:                         1.732e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -4710.5951   2.34e+04     -0.202      0.840   -5.05e+04    4.11e+04
# Rooms          3.238e+05   6892.634     46.975      0.000     3.1e+05    3.37e+05
# Car            1.255e+04   7643.529      1.641      0.101   -2437.753    2.75e+04
# Propertycount    12.7549      1.573      8.108      0.000       9.671      15.839
# ==============================================================================
# Omnibus:                      914.505   Durbin-Watson:                   1.324
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1576.575
# Skew:                           0.998   Prob(JB):                         0.00
# Kurtosis:                       4.522   Cond. No.                     3.29e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.29e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columnas:  Rooms , Car y Lattitude
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.380
# Model:                            OLS   Adj. R-squared:                  0.379
# Method:                 Least Squares   F-statistic:                     1224.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:49:02   Log-Likelihood:                -86268.
# No. Observations:                6005   AIC:                         1.725e+05
# Df Residuals:                    6001   BIC:                         1.726e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -7.895e+07   2.97e+06    -26.611      0.000   -8.48e+07   -7.31e+07
# Rooms       3.245e+05   6524.730     49.727      0.000    3.12e+05    3.37e+05
# Car         9091.0136   7263.480      1.252      0.211   -5148.018    2.33e+04
# Lattitude  -2.091e+06   7.85e+04    -26.647      0.000   -2.24e+06   -1.94e+06
# ==============================================================================
# Omnibus:                      925.627   Durbin-Watson:                   1.407
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1676.333
# Skew:                           0.984   Prob(JB):                         0.00
# Kurtosis:                       4.681   Cond. No.                     2.08e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.08e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columnas:  Rooms , Car y Longtitude
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.338
# Model:                            OLS   Adj. R-squared:                  0.337
# Method:                 Least Squares   F-statistic:                     1019.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:49:02   Log-Likelihood:                -86465.
# No. Observations:                6005   AIC:                         1.729e+05
# Df Residuals:                    6001   BIC:                         1.730e+05
# ...
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -6.846e+07   2.78e+06    -24.586      0.000   -7.39e+07    -6.3e+07
# BuildingArea   5370.9855     81.835     65.632      0.000    5210.559    5531.412
# Propertycount     9.9061      1.401      7.071      0.000       7.160      12.653
# Lattitude     -1.817e+06   7.37e+04    -24.670      0.000   -1.96e+06   -1.67e+06
# ==============================================================================
# Omnibus:                      971.384   Durbin-Watson:                   1.528
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2279.603
# Skew:                           0.923   Prob(JB):                         0.00
# Kurtosis:                       5.388   Cond. No.                     4.31e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.31e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columnas:  BuildingArea , Propertycount y Longtitude
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.422
# Model:                            OLS   Adj. R-squared:                  0.421
# Method:                 Least Squares   F-statistic:                     1458.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:49:05   Log-Likelihood:                -86058.
# No. Observations:                6005   AIC:                         1.721e+05
# Df Residuals:                    6001   BIC:                         1.721e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -1.285e+08   8.43e+06    -15.237      0.000   -1.45e+08   -1.12e+08
# BuildingArea   5233.0627     85.117     61.481      0.000    5066.202    5399.923
# Propertycount     9.3066      1.451      6.414      0.000       6.462      12.151
# Longtitude     8.878e+05   5.82e+04     15.264      0.000    7.74e+05       1e+06
# ==============================================================================
# Omnibus:                      968.208   Durbin-Watson:                   1.478
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2153.875
# Skew:                           0.939   Prob(JB):                         0.00
# Kurtosis:                       5.253   Cond. No.                     1.27e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.27e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columnas:  BuildingArea , Lattitude y Longtitude
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.456
# Model:                            OLS   Adj. R-squared:                  0.456
# Method:                 Least Squares   F-statistic:                     1678.
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):               0.00
# Time:                        23:49:05   Log-Likelihood:                -85872.
# No. Observations:                6005   AIC:                         1.718e+05
# Df Residuals:                    6001   BIC:                         1.718e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const        -1.332e+08   8.11e+06    -16.418      0.000   -1.49e+08   -1.17e+08
# BuildingArea  5219.1781     81.971     63.671      0.000    5058.485    5379.872
# Lattitude    -1.619e+06   7.84e+04    -20.639      0.000   -1.77e+06   -1.47e+06
# Longtitude     4.99e+05   5.98e+04      8.345      0.000    3.82e+05    6.16e+05
# ==============================================================================
# Omnibus:                      975.565   Durbin-Watson:                   1.533
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2237.653
# Skew:                           0.935   Prob(JB):                         0.00
# Kurtosis:                       5.334   Cond. No.                     3.29e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.29e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columnas:  YearBuilt , Propertycount y Lattitude
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.187
# Model:                            OLS   Adj. R-squared:                  0.187
# Method:                 Least Squares   F-statistic:                     460.8
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):          1.81e-269
# Time:                        23:49:05   Log-Likelihood:                -87079.
# No. Observations:                6005   AIC:                         1.742e+05
# Df Residuals:                    6001   BIC:                         1.742e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -5.641e+07   3.44e+06    -16.415      0.000   -6.31e+07   -4.97e+07
# YearBuilt     -5130.6947    169.304    -30.305      0.000   -5462.591   -4798.798
# Propertycount    -2.1114      1.702     -1.240      0.215      -5.448       1.225
# Lattitude     -1.786e+06      9e+04    -19.845      0.000   -1.96e+06   -1.61e+06
# ==============================================================================
# Omnibus:                      985.693   Durbin-Watson:                   1.563
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1734.807
# Skew:                           1.057   Prob(JB):                         0.00
# Kurtosis:                       4.570   Cond. No.                     4.46e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.46e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columnas:  YearBuilt , Propertycount y Longtitude
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.194
# Model:                            OLS   Adj. R-squared:                  0.194
# Method:                 Least Squares   F-statistic:                     481.5
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):          2.43e-280
# Time:                        23:49:05   Log-Likelihood:                -87054.
# No. Observations:                6005   AIC:                         1.741e+05
# Df Residuals:                    6001   BIC:                         1.741e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -1.968e+08   9.85e+06    -19.977      0.000   -2.16e+08   -1.78e+08
# YearBuilt     -5372.6250    168.382    -31.907      0.000   -5702.714   -5042.536
# Propertycount    -4.0987      1.702     -2.408      0.016      -7.436      -0.761
# Longtitude     1.438e+06    6.8e+04     21.153      0.000     1.3e+06    1.57e+06
# ==============================================================================
# Omnibus:                     1080.264   Durbin-Watson:                   1.603
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1985.868
# Skew:                           1.126   Prob(JB):                         0.00
# Kurtosis:                       4.693   Cond. No.                     1.28e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.28e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columnas:  YearBuilt , Lattitude y Longtitude
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.217
# Model:                            OLS   Adj. R-squared:                  0.217
# Method:                 Least Squares   F-statistic:                     554.7
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):          3.30e-318
# Time:                        23:49:05   Log-Likelihood:                -86966.
# No. Observations:                6005   AIC:                         1.739e+05
# Df Residuals:                    6001   BIC:                         1.740e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.936e+08   9.66e+06    -20.048      0.000   -2.13e+08   -1.75e+08
# YearBuilt  -5207.2128    166.094    -31.351      0.000   -5532.816   -4881.609
# Lattitude  -1.275e+06   9.43e+04    -13.529      0.000   -1.46e+06   -1.09e+06
# Longtitude   1.08e+06   7.12e+04     15.181      0.000    9.41e+05    1.22e+06
# ==============================================================================
# Omnibus:                      981.749   Durbin-Watson:                   1.629
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1763.094
# Skew:                           1.042   Prob(JB):                         0.00
# Kurtosis:                       4.644   Cond. No.                     3.13e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.13e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Columnas:  Propertycount , Lattitude y Longtitude
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.089
# Model:                            OLS   Adj. R-squared:                  0.089
# Method:                 Least Squares   F-statistic:                     195.6
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):          5.16e-121
# Time:                        23:49:05   Log-Likelihood:                -87421.
# No. Observations:                6005   AIC:                         1.749e+05
# Df Residuals:                    6001   BIC:                         1.749e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -2.012e+08   1.05e+07    -19.215      0.000   -2.22e+08   -1.81e+08
# Propertycount    -2.0025      1.808     -1.107      0.268      -5.547       1.542
# Lattitude     -1.469e+06   1.01e+05    -14.473      0.000   -1.67e+06   -1.27e+06
# Longtitude     1.012e+06    7.7e+04     13.137      0.000    8.61e+05    1.16e+06
# ==============================================================================
# Omnibus:                      842.599   Durbin-Watson:                   1.599
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1295.459
# Skew:                           0.996   Prob(JB):                    4.95e-282
# Kurtosis:                       4.098   Cond. No.                     1.25e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.25e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Mejor R-squared: 0.5842266870910938
# Mejor columnas: ('BuildingArea', 'YearBuilt', 'Lattitude')
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
